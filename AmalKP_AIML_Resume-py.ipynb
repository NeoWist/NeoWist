# %%
# !pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Create a new Document
doc = Document()

# Function to add sections to the document
def add_section(title, content):
    # Add title
    doc.add_heading(title, level=1).alignment = WD_PARAGRAPH_ALIGNMENT.LEFT

    # Add content
    doc.add_paragraph(content)
# Add Name
doc.add_heading("Amal K P", level=0).alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
# Add Contact Information
add_section("Contact:", "- Address: Kokkandathil House, Kuttichira - 680724, Chalakudy, Kerala, India\n"
                        "- Email: amalkp814@gmail.com\n"
                        "- Phone: +91 8304024201\n"
                        "- LinkedIn: https://www.linkedin.com/in/amalkp814/\n"
                        "- GitHub: https://github.com/NeoWist")

#doc.add_page_break()

# Add Objective
add_section("Objective:", "Motivated AI/ML Engineer with a strong academic background and hands-on experience in machine learning, data analysis, and software development. Eager to contribute innovative solutions to real-world problems and thrive in a collaborative and growth-focused environment.")

#doc.add_page_break()

# Add Professional Experience Section
add_section("Professional Experience:", "- Data Science & Machine Learning Internship\n"
                                      "  - Gilbert Research Center, Jul 2023 - Sep 2023 \n"
                                      "    - Completed Data Science & Machine Learning Internship, gaining comprehensive knowledge in mathematics, Python programming, statistics, and machine learning.\n"
                                      "    - Explored advanced topics including neural networks, deep learning, and image processing, particularly in the context of medical imaging.\n"
                                      "    - Received a Verified Certificate and a Letter of Recommendation from Gilbert Research Center.\n"
                                      "\n"
                                      "- Electronics and Instrumentation Engineer\n"
                                      "  - K J Bee Farm, Jul 2019 - Jul 2023 \n"
                                      "    - Acquired expertise in designing systems to reduce honey moisture and ensure food safety using temperature and humidity monitoring and controlling, by making use of different sensors and control units.\n"
                                      "    - Set up an air filtering system for the honey packing unit.\n"
                                      "    - Led the development of honey extraction machines and related tools.\n"
                                      "    - Demonstrated strong troubleshooting and problem-solving skills.")
#doc.add_page_break()

# Add Education Section
add_section("Education:", "- Master's Certification Programs:\n"
                          "  - Simplilearn Academy\n"
                          "    - Artificial Intelligence Engineer, Dec 2021 - Dec 2023\n"
                          "    - Enrolled in the Artificial Intelligence Engineer program, focusing on data analysis, Python programming, and machine learning."
                          "    - Studying computer vision techniques, natural language processing, and mathematics and statistics for data science.\n"
                          "\n"
                          "- M.Tech:\n"
                          "  - College of Engineering, Thiruvananthapuram\n"
                          "    - Master of Technology (M.Tech), Applied Electronics and Instrumentation Engineering, 2017 - 2020\n"
                          "    - CGPA: 7.02\n"
                          "    - Activities and Achievements:\n"
                          "      - Seminar on MACHINE LEARNING organized by IEEE Signal Processing Society, Kerala Chapter on 16-2-2018\n"
                          "      - Internship in 'Industrial Automation' from 'Bosch Rexroth - CET Centre of Excellence In Automation Technologies' from 31-01-2018 to 28-02-2018."
                          "        The topics covered are Hydraulics, Pneumatics, Sensorics Technology, and Programmable Logic controllers in line with the training methods developed with Bosch Rexroth.\n"
                          "      - Project on 'Low-cost Automated Honey Processing unit' aimed to reduce honey moisture by utilizing microcontroller, sensors, and dehumidifying units as an individual main project.\n"
                          "      - Project on 'Remote patient movement and vital sign monitoring' for bedridden and elderly patients as a group mini-project.\n"
                          "\n"
                          "- B.Tech:\n"
                          "  - College of Engineering Chengannur\n"
                          "    - Bachelor of Technology (B.Tech), Electronics And Instrumentation Engineering, 2012 - 2016\n"
                          "    - CGPA: 7.19\n"
                          "    - Activities and Achievements:\n"
                          "      - Internship in 'Internet Of Things (IoT)' at ICFOSS Technopark, Trivandrum, from 9-06-2015 to 30-06-2015\n"
                          "      - Workshop on 'Internet Of Things (IoT)' at ICFOSS Technopark, Trivandrum, from 6-06-2015 to 8-06-2015\n"
                          "      - Project on 'Restaurant automation' using a touch screen tabletop menu, a serving robot, and a communication and control interface system to the kitchen using Python, Arduino, RaspberryPi, etc. as a group main project.\n"
                          "      - Project on 'Pet Plant', a system to monitor plant surroundings and provides automatic watering and warning systems for the user and facilitates a better growth environment for plants.\n"
                          "      - Training course in 'DCS and PLC Overview' conducted by 'Technical school of YOKOGAWA India Ltd.' from 18-2-2016 to 22-2-2016\n"
                          "      - Internship at 'Walrus Marine & Engineering Co, Pvt. Ltd.' from 22-05-2015 to 5-05-2015. Familiarized with operations and functions of various automation systems like PLC, SCADA, and HMI.\n"
                          "      - Industrial visits on 26-05-2015 to Modern Food Industries ltd, Eranakulam, on 30-04-2014 to FACT Ltd, Eranakulam, etc\n"
                          "      - Workshop on SCILAB and RaspberryPi from IEEE ISQUIP at CEC, Chengannur, from 27-05-2015 to 31-05-2015.\n"
                          "      - 2-week internship in 'Robotics and Embedded Systems' conducted by Techjeeva.\n")

#doc.add_page_break()

# Add Skills Section
add_section("Skills:", "- Python Programming "
                      "- Systems Design "
                      "- Troubleshooting "
                      "- Project Management "
                      "- Data Analysis and Interpretation "
                      "- Machine Learning Algorithms "
                      "- Deep Learning with Keras and TensorFlow "
                      "- Computer Vision Techniques "
                      "- Natural Language Processing (NLP) "
                      "- IoT (Internet of Things) "
                      "- C "
                      "- C++ "
                      "- MikroC "
                      "- Arduino "
                      "- Microsoft Office "
                      "- Matlab "
                      "- LabVIEW "
                      "- Electronics and Instrumentation Engineering "
                      "- Industrial Automation "
                      "- SCADA (Supervisory Control and Data Acquisition) "
                      "- HMI (Human-Machine Interface) "
                      "- Proteus "
                      "- Diptrace "
                      "- PLC Programming "
                      "- Linux (Ubuntu, Raspbian, etc.) "
                      "- Windows ")


#doc.add_page_break()

# Add Certifications and Achievements Section
add_section("Certifications and Achievements:", "- Featured in local news for building a sanitization tunnel during the COVID crisis with two friends.\n"
                                                "- Featured in two different newspapers during B.Tech:\n"
                                                "  - Developed an automatic waste bin called 'Green Bin' with a group of colleagues, associated with Thiruvananthapuram Railway Division, promoting cleanliness.")

# Save the document
doc.save('AmalKP_AIML_Resume.docx')
